# %%
import pandas as pd

df_list = []
tahun = 2010
# while tahun < 2024:
#     data = pd.read_excel("dataset.xlsx", sheet_name=tahun)

for year in range(2010, 2024):
    # Read data from each sheet and append it to the list
    df = pd.read_excel("dataset1.xlsx", sheet_name=str(year))
    df_list.append(df)

data = pd.concat(df_list, ignore_index=True)

data
# Out:
#       provinsi     kabupaten   tahun indeks_pembangunan_manusia  \
# 0         ACEH          ACEH  2010.0                      67.09
# 1         ACEH      Simeulue  2010.0                       60.6
# 2         ACEH   AcehSingkil  2010.0                      62.36
# 3         ACEH   AcehSelatan  2010.0                      61.22
# 4         ACEH  AcehTenggara  2010.0                      63.82
# ...        ...           ...     ...                        ...
# 13139     ACEH   AcehSingkil     NaN                        NaN
# 13140     ACEH   AcehSelatan     NaN                        NaN
# 13141     ACEH  AcehTenggara     NaN                        NaN
# 13142     ACEH     AcehTimur     NaN                        NaN
# 13143     ACEH    AcehTengah     NaN                        NaN
#
#       angka_harapan_hidup_laki angka_harapan_hidup_perempuan  \
# 0                        67.17                         71.09
# 1                        62.15                         65.84
# 2                        64.76                         68.55
# 3                        61.04                         64.69
# 4                         64.9                         68.69
# ...                        ...                           ...
# 13139                      NaN                           NaN
# 13140                      NaN                           NaN
# 13141                      NaN                           NaN
# 13142                      NaN                           NaN
# 13143                      NaN                           NaN
#
#       rerata_lama_sekolah_laki rerata_lama_sekolah_perempuan  \
# 0                         8.57                          7.76
# 1                         8.45                          7.36
# 2                         7.44                          5.85
# 3                         7.95           2024-01-07 00:00:00
# 4                         8.94                          7.54
# ...                        ...                           ...
# 13139                      NaN                           NaN
# 13140                      NaN                           NaN
# 13141                      NaN                           NaN
# 13142                      NaN                           NaN
# 13143                      NaN                           NaN
#
#       harapan_lama_sekolah pengeluaran_per_kapita
# 0                     12.9                   7934
# 1                    12.45                   5728
# 2                    12.41                   7081
# 3                    12.35                   6855
# 4                    12.43                   6663
# ...                    ...                    ...
# 13139                  NaN                    NaN
# 13140                  NaN                    NaN
# 13141                  NaN                    NaN
# 13142                  NaN                    NaN
# 13143                  NaN                    NaN
#
# [13144 rows x 10 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13144 entries, 0 to 13143
# Data columns (total 10 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   provinsi                       7694 non-null   object
#  1   kabupaten                      7694 non-null   object
#  2   tahun                          7686 non-null   float64
#  3   indeks_pembangunan_manusia     7686 non-null   object
#  4   angka_harapan_hidup_laki       7686 non-null   object
#  5   angka_harapan_hidup_perempuan  7686 non-null   object
#  6   rerata_lama_sekolah_laki       7686 non-null   object
#  7   rerata_lama_sekolah_perempuan  7686 non-null   object
#  8   harapan_lama_sekolah           7320 non-null   object
#  9   pengeluaran_per_kapita         7686 non-null   object
# dtypes: float64(1), object(9)
# memory usage: 1.0+ MB

# %%
data = data.drop(columns=["provinsi", "kabupaten", "tahun"])
data
# Out:
#       indeks_pembangunan_manusia angka_harapan_hidup_laki  \
# 0                          67.09                    67.17
# 1                           60.6                    62.15
# 2                          62.36                    64.76
# 3                          61.22                    61.04
# 4                          63.82                     64.9
# ...                          ...                      ...
# 13139                        NaN                      NaN
# 13140                        NaN                      NaN
# 13141                        NaN                      NaN
# 13142                        NaN                      NaN
# 13143                        NaN                      NaN
#
#       angka_harapan_hidup_perempuan rerata_lama_sekolah_laki  \
# 0                             71.09                     8.57
# 1                             65.84                     8.45
# 2                             68.55                     7.44
# 3                             64.69                     7.95
# 4                             68.69                     8.94
# ...                             ...                      ...
# 13139                           NaN                      NaN
# 13140                           NaN                      NaN
# 13141                           NaN                      NaN
# 13142                           NaN                      NaN
# 13143                           NaN                      NaN
#
#       rerata_lama_sekolah_perempuan harapan_lama_sekolah  \
# 0                              7.76                 12.9
# 1                              7.36                12.45
# 2                              5.85                12.41
# 3               2024-01-07 00:00:00                12.35
# 4                              7.54                12.43
# ...                             ...                  ...
# 13139                           NaN                  NaN
# 13140                           NaN                  NaN
# 13141                           NaN                  NaN
# 13142                           NaN                  NaN
# 13143                           NaN                  NaN
#
#       pengeluaran_per_kapita
# 0                       7934
# 1                       5728
# 2                       7081
# 3                       6855
# 4                       6663
# ...                      ...
# 13139                    NaN
# 13140                    NaN
# 13141                    NaN
# 13142                    NaN
# 13143                    NaN
#
# [13144 rows x 7 columns]

# %%
data = data.dropna()
data
# Out:
#      indeks_pembangunan_manusia angka_harapan_hidup_laki  \
# 0                         67.09                    67.17
# 1                          60.6                    62.15
# 2                         62.36                    64.76
# 3                         61.22                    61.04
# 4                         63.82                     64.9
# ...                         ...                      ...
# 7681                       56.7                    64.48
# 7682                      50.19                    64.22
# 7683                      51.18                    64.04
# 7684                      81.14                    69.14
# 7685                      73.55                    70.17
#
#      angka_harapan_hidup_perempuan rerata_lama_sekolah_laki  \
# 0                            71.09                     8.57
# 1                            65.84                     8.45
# 2                            68.55                     7.44
# 3                            64.69                     7.95
# 4                            68.69                     8.94
# ...                            ...                      ...
# 7681                         68.39                     5.45
# 7682                         68.11                     4.76
# 7683                         67.92      2024-04-04 00:00:00
# 7684                          73.1                    12.17
# 7685                         74.18      2024-07-09 00:00:00
#
#      rerata_lama_sekolah_perempuan harapan_lama_sekolah pengeluaran_per_kapita
# 0                             7.76                 12.9                   7934
# 1                             7.36                12.45                   5728
# 2                             5.85                12.41                   7081
# 3              2024-01-07 00:00:00                12.35                   6855
# 4                             7.54                12.43                   6663
# ...                            ...                  ...                    ...
# 7681                          4.13                10.62                 6182.0
# 7682           2024-06-02 00:00:00                 7.69                 6140.0
# 7683                          1.83                 9.85                 5104.0
# 7684                         11.67                15.26                15272.0
# 7685                          8.48                13.15                11899.0
#
# [7320 rows x 7 columns]

# %%
from datetime import datetime


is_datetime_row = data.map(lambda x: isinstance(x, datetime)).any(axis=1)
data = data[is_datetime_row == False]
data
# Out:
#      indeks_pembangunan_manusia angka_harapan_hidup_laki  \
# 0                         67.09                    67.17
# 1                          60.6                    62.15
# 2                         62.36                    64.76
# 4                         63.82                     64.9
# 5                         61.75                    65.95
# ...                         ...                      ...
# 7678                      50.22                    62.28
# 7679                      50.87                    64.05
# 7680                      44.59                    64.57
# 7681                       56.7                    64.48
# 7684                      81.14                    69.14
#
#      angka_harapan_hidup_perempuan rerata_lama_sekolah_laki  \
# 0                            71.09                     8.57
# 1                            65.84                     8.45
# 2                            68.55                     7.44
# 4                            68.69                     8.94
# 5                            69.77                     7.34
# ...                            ...                      ...
# 7678                         66.09                     5.27
# 7679                         67.94                     5.13
# 7680                          68.4                     2.77
# 7681                         68.39                     5.45
# 7684                          73.1                    12.17
#
#      rerata_lama_sekolah_perempuan harapan_lama_sekolah pengeluaran_per_kapita
# 0                             7.76                 12.9                   7934
# 1                             7.36                12.45                   5728
# 2                             5.85                12.41                   7081
# 4                             7.54                12.43                   6663
# 5                             6.48                11.54                   6614
# ...                            ...                  ...                    ...
# 7678                          2.67                 9.62                 4855.0
# 7679                          3.34                 9.66                 5015.0
# 7680                          1.37                 5.59                 5975.0
# 7681                          4.13                10.62                 6182.0
# 7684                         11.67                15.26                15272.0
#
# [4898 rows x 7 columns]

# %%
mask = data.apply(lambda row: '-' not in row.values, axis=1)
data = data[mask]
data
# Out:
#      indeks_pembangunan_manusia angka_harapan_hidup_laki  \
# 0                         67.09                    67.17
# 1                          60.6                    62.15
# 2                         62.36                    64.76
# 4                         63.82                     64.9
# 5                         61.75                    65.95
# ...                         ...                      ...
# 7678                      50.22                    62.28
# 7679                      50.87                    64.05
# 7680                      44.59                    64.57
# 7681                       56.7                    64.48
# 7684                      81.14                    69.14
#
#      angka_harapan_hidup_perempuan rerata_lama_sekolah_laki  \
# 0                            71.09                     8.57
# 1                            65.84                     8.45
# 2                            68.55                     7.44
# 4                            68.69                     8.94
# 5                            69.77                     7.34
# ...                            ...                      ...
# 7678                         66.09                     5.27
# 7679                         67.94                     5.13
# 7680                          68.4                     2.77
# 7681                         68.39                     5.45
# 7684                          73.1                    12.17
#
#      rerata_lama_sekolah_perempuan harapan_lama_sekolah pengeluaran_per_kapita
# 0                             7.76                 12.9                   7934
# 1                             7.36                12.45                   5728
# 2                             5.85                12.41                   7081
# 4                             7.54                12.43                   6663
# 5                             6.48                11.54                   6614
# ...                            ...                  ...                    ...
# 7678                          2.67                 9.62                 4855.0
# 7679                          3.34                 9.66                 5015.0
# 7680                          1.37                 5.59                 5975.0
# 7681                          4.13                10.62                 6182.0
# 7684                         11.67                15.26                15272.0
#
# [4316 rows x 7 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4316 entries, 0 to 7684
# Data columns (total 7 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   indeks_pembangunan_manusia     4316 non-null   object
#  1   angka_harapan_hidup_laki       4316 non-null   object
#  2   angka_harapan_hidup_perempuan  4316 non-null   object
#  3   rerata_lama_sekolah_laki       4316 non-null   object
#  4   rerata_lama_sekolah_perempuan  4316 non-null   object
#  5   harapan_lama_sekolah           4316 non-null   object
#  6   pengeluaran_per_kapita         4316 non-null   object
# dtypes: object(7)
# memory usage: 269.8+ KB

# %%
data = data.apply(pd.to_numeric, errors='coerce')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4316 entries, 0 to 7684
# Data columns (total 7 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   indeks_pembangunan_manusia     4316 non-null   float64
#  1   angka_harapan_hidup_laki       4316 non-null   float64
#  2   angka_harapan_hidup_perempuan  4316 non-null   float64
#  3   rerata_lama_sekolah_laki       4316 non-null   float64
#  4   rerata_lama_sekolah_perempuan  4316 non-null   float64
#  5   harapan_lama_sekolah           4316 non-null   float64
#  6   pengeluaran_per_kapita         4316 non-null   int64
# dtypes: float64(6), int64(1)
# memory usage: 269.8 KB

# %%
data['angka_harapan_hidup'] = (data['angka_harapan_hidup_laki'] + data['angka_harapan_hidup_perempuan']) / 2
data['rerata_lama_sekolah'] = (data['rerata_lama_sekolah_laki'] + data['rerata_lama_sekolah_perempuan']) / 2
data
# Out:
#       indeks_pembangunan_manusia  angka_harapan_hidup_laki  \
# 0                          67.09                     67.17
# 1                          60.60                     62.15
# 2                          62.36                     64.76
# 4                          63.82                     64.90
# 5                          61.75                     65.95
# ...                          ...                       ...
# 7678                       50.22                     62.28
# 7679                       50.87                     64.05
# 7680                       44.59                     64.57
# 7681                       56.70                     64.48
# 7684                       81.14                     69.14
#
#       angka_harapan_hidup_perempuan  rerata_lama_sekolah_laki  \
# 0                             71.09                      8.57
# 1                             65.84                      8.45
# 2                             68.55                      7.44
# 4                             68.69                      8.94
# 5                             69.77                      7.34
# ...                             ...                       ...
# 7678                          66.09                      5.27
# 7679                          67.94                      5.13
# 7680                          68.40                      2.77
# 7681                          68.39                      5.45
# 7684                          73.10                     12.17
#
#       rerata_lama_sekolah_perempuan  harapan_lama_sekolah  \
# 0                              7.76                 12.90
# 1                              7.36                 12.45
# 2                              5.85                 12.41
# 4                              7.54                 12.43
# 5                              6.48                 11.54
# ...                             ...                   ...
# 7678                           2.67                  9.62
# 7679                           3.34                  9.66
# 7680                           1.37                  5.59
# 7681                           4.13                 10.62
# 7684                          11.67                 15.26
#
#       pengeluaran_per_kapita  angka_harapan_hidup  rerata_lama_sekolah
# 0                       7934               69.130                8.165
# 1                       5728               63.995                7.905
# 2                       7081               66.655                6.645
# 4                       6663               66.795                8.240
# 5                       6614               67.860                6.910
# ...                      ...                  ...                  ...
# 7678                    4855               64.185                3.970
# 7679                    5015               65.995                4.235
# 7680                    5975               66.485                2.070
# 7681                    6182               66.435                4.790
# 7684                   15272               71.120               11.920
#
# [4316 rows x 9 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4316 entries, 0 to 7684
# Data columns (total 9 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   indeks_pembangunan_manusia     4316 non-null   float64
#  1   angka_harapan_hidup_laki       4316 non-null   float64
#  2   angka_harapan_hidup_perempuan  4316 non-null   float64
#  3   rerata_lama_sekolah_laki       4316 non-null   float64
#  4   rerata_lama_sekolah_perempuan  4316 non-null   float64
#  5   harapan_lama_sekolah           4316 non-null   float64
#  6   pengeluaran_per_kapita         4316 non-null   int64
#  7   angka_harapan_hidup            4316 non-null   float64
#  8   rerata_lama_sekolah            4316 non-null   float64
# dtypes: float64(8), int64(1)
# memory usage: 337.2 KB

# %%
data = data.drop(columns=['angka_harapan_hidup_laki', 'angka_harapan_hidup_perempuan', 'rerata_lama_sekolah_laki', 'rerata_lama_sekolah_perempuan'])
data
# Out:
#       indeks_pembangunan_manusia  harapan_lama_sekolah  \
# 0                          67.09                 12.90
# 1                          60.60                 12.45
# 2                          62.36                 12.41
# 4                          63.82                 12.43
# 5                          61.75                 11.54
# ...                          ...                   ...
# 7678                       50.22                  9.62
# 7679                       50.87                  9.66
# 7680                       44.59                  5.59
# 7681                       56.70                 10.62
# 7684                       81.14                 15.26
#
#       pengeluaran_per_kapita  angka_harapan_hidup  rerata_lama_sekolah
# 0                       7934               69.130                8.165
# 1                       5728               63.995                7.905
# 2                       7081               66.655                6.645
# 4                       6663               66.795                8.240
# 5                       6614               67.860                6.910
# ...                      ...                  ...                  ...
# 7678                    4855               64.185                3.970
# 7679                    5015               65.995                4.235
# 7680                    5975               66.485                2.070
# 7681                    6182               66.435                4.790
# 7684                   15272               71.120               11.920
#
# [4316 rows x 5 columns]

# %%
import matplotlib.pyplot as plt

fig, axes = plt.subplots(nrows=2, ncols=3, figsize=(10, 8))
data.boxplot(column=["indeks_pembangunan_manusia"], ax=axes[0, 0])

data.boxplot(column=["harapan_lama_sekolah"], ax=axes[0, 1])

data.boxplot(column=["pengeluaran_per_kapita"], ax=axes[0, 2])

data.boxplot(column=["angka_harapan_hidup"], ax=axes[1, 0])

data.boxplot(column=["rerata_lama_sekolah"], ax=axes[1, 1])

plt.tight_layout()
plt.show()

# %%
data.corr()
# Out:
#                             indeks_pembangunan_manusia  harapan_lama_sekolah  \
# indeks_pembangunan_manusia                    1.000000              0.812321
# harapan_lama_sekolah                          0.812321              1.000000
# pengeluaran_per_kapita                        0.863553              0.536072
# angka_harapan_hidup                           0.707517              0.401625
# rerata_lama_sekolah                           0.877843              0.779600
#
#                             pengeluaran_per_kapita  angka_harapan_hidup  \
# indeks_pembangunan_manusia                0.863553             0.707517
# harapan_lama_sekolah                      0.536072             0.401625
# pengeluaran_per_kapita                    1.000000             0.564539
# angka_harapan_hidup                       0.564539             1.000000
# rerata_lama_sekolah                       0.685378             0.441674
#
#                             rerata_lama_sekolah
# indeks_pembangunan_manusia             0.877843
# harapan_lama_sekolah                   0.779600
# pengeluaran_per_kapita                 0.685378
# angka_harapan_hidup                    0.441674
# rerata_lama_sekolah                    1.000000

# %%
import seaborn as sns
sns.histplot(data["indeks_pembangunan_manusia"], kde=True)
plt.title('Histogram dari RR')
plt.show()

# %%
print("Shape data:", data.shape)
# Out:
# Shape data: (4316, 5)

# %%
data_normalized = (data - data.min()) / (data.max() - data.min())
data_normalized
# Out:
#       indeks_pembangunan_manusia  harapan_lama_sekolah  \
# 0                       0.691378              0.698983
# 1                       0.596854              0.672053
# 2                       0.622488              0.669659
# 4                       0.643752              0.670856
# 5                       0.613603              0.617594
# ...                          ...                   ...
# 7678                    0.445674              0.502693
# 7679                    0.455141              0.505087
# 7680                    0.363676              0.261520
# 7681                    0.540052              0.562537
# 7684                    0.896009              0.840215
#
#       pengeluaran_per_kapita  angka_harapan_hidup  rerata_lama_sekolah
# 0                   0.234255             0.651814             0.620541
# 1                   0.124770             0.449330             0.600157
# 2                   0.191920             0.554219             0.501372
# 4                   0.171175             0.559740             0.626421
# 5                   0.168743             0.601735             0.522148
# ...                      ...                  ...                  ...
# 7678                0.081443             0.456822             0.291650
# 7679                0.089384             0.528194             0.312426
# 7680                0.137029             0.547516             0.142689
# 7681                0.147303             0.545544             0.355939
# 7684                0.598442             0.730284             0.914935
#
# [4316 rows x 5 columns]
